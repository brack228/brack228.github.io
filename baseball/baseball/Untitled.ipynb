# %%
import pandas as pd

# %%
bat=pd.read_csv('batting_leaders.csv')

# %%
del bat['Unnamed: 0']

# %%
bat['diff']=bat['preds']-bat['wOBA_current_year']

# %%
bat[bat['Name']]

# %%
bat.sort_values('diff',ascending=True)[bat['wOBA_current_year']<0.39]
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                      Name  wOBA_current_year     preds      diff
# 183        Derek Dietrich              0.383  0.338937 -0.044063
# 139            Tom Murphy              0.378  0.346707 -0.031293
# 193     Robinson Chirinos              0.365  0.337246 -0.027754
# 69         Mike Moustakas              0.387  0.359492 -0.027508
# 112         Shin-Soo Choo              0.379  0.352196 -0.026804
# 156         Oscar Mercado              0.369  0.343182 -0.025818
# 78            Nelson Cruz              0.383  0.358612 -0.024388
# 47              Max Muncy              0.387  0.364533 -0.022467
# 39         Carlos Santana              0.388  0.366822 -0.021178
# 75           Trey Mancini              0.380  0.358828 -0.021172
# 70        Yasmani Grandal              0.380  0.359431 -0.020569
# ...
